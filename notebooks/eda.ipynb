# %%
import pandas as pd

# %%
# ACNC data - Australian charities as of FY23
path = "../data/datadotgov_main.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    ABN                     Charity_Legal_Name Other_Organisation_Names  \
# 0  NaN                                    NaN                      NaN
# 1  NaN                                    NaN                      NaN
# 2  NaN                                    NaN                      NaN
# 3  NaN                     PAF 1023421-B4G9D2                      NaN
# 4  NaN  Private Ancillary Fund 1206428-P3J2T0                      NaN
#
#   Address_Type Address_Line_1 Address_Line_2 Address_Line_3 Town_City State  \
# 0     Business            NaN            NaN            NaN       NaN   NaN
# 1     Business            NaN            NaN            NaN       NaN   NaN
# 2     Business            NaN            NaN            NaN       NaN   NaN
# 3     Business            NaN            NaN            NaN       NaN   NaN
# 4     Business            NaN            NaN            NaN       NaN   NaN
#
#   Postcode  ... Pre_Post_Release_Offenders Rural_Regional_Remote_Communities  \
# 0      NaN  ...                        NaN                               NaN
# 1      NaN  ...                        NaN                               NaN
# 2      NaN  ...                        NaN                               NaN
# 3      NaN  ...                        NaN                               NaN
# 4      NaN  ...                        NaN                               NaN
#
#   Unemployed_Person Veterans_or_their_families Victims_of_crime  \
# 0               NaN                        NaN              NaN
# 1               NaN                        NaN              NaN
# 2               NaN                        NaN              NaN
# 3               NaN                        NaN              NaN
# 4               NaN                        NaN              NaN
#
#    Victims_of_Disasters Youth animals environment other_gender_identities
# 0                   NaN   NaN     NaN         NaN                     NaN
# 1                   NaN   NaN     NaN         NaN                     NaN
# 2                   NaN   NaN     NaN         NaN                     NaN
# 3                   NaN   NaN     NaN         NaN                     NaN
# 4                   NaN   NaN     NaN         NaN                     NaN
#
# [5 rows x 69 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62262 entries, 0 to 62261
# Data columns (total 69 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   ABN                                                             61791 non-null  float64
#  1   Charity_Legal_Name                                              61957 non-null  object
#  2   Other_Organisation_Names                                        5471 non-null   object
#  3   Address_Type                                                    62262 non-null  object
#  4   Address_Line_1                                                  55644 non-null  object
#  5   Address_Line_2                                                  5173 non-null   object
#  6   Address_Line_3                                                  630 non-null    object
#  7   Town_City                                                       55647 non-null  object
#  8   State                                                           55559 non-null  object
#  9   Postcode                                                        55723 non-null  object
#  10  Country                                                         54646 non-null  object
#  11  Charity_Website                                                 40280 non-null  object
#  12  Registration_Date                                               61914 non-null  object
#  13  Date_Organisation_Established                                   59100 non-null  object
#  14  Charity_Size                                                    55448 non-null  object
#  15  Number_of_Responsible_Persons                                   62262 non-null  int64
#  16  Financial_Year_End                                              62242 non-null  object
#  17  Operates_in_ACT                                                 2650 non-null   object
#  18  Operates_in_NSW                                                 18072 non-null  object
#  19  Operates_in_NT                                                  2340 non-null   object
#  20  Operates_in_QLD                                                 10129 non-null  object
#  21  Operates_in_SA                                                  5404 non-null   object
#  22  Operates_in_TAS                                                 2855 non-null   object
#  23  Operates_in_VIC                                                 13832 non-null  object
#  24  Operates_in_WA                                                  6719 non-null   object
#  25  Operating_Countries                                             4406 non-null   object
#  26  PBI                                                             12206 non-null  object
#  27  HPC                                                             2554 non-null   object
#  28  Preventing_or_relieving_suffering_of_animals                    1169 non-null   object
#  29  Advancing_Culture                                               5407 non-null   object
#  30  Advancing_Education                                             12557 non-null  object
#  31  Advancing_Health                                                6555 non-null   object
#  32  Promote_or_oppose_a_change_to_law__government_poll_or_prac      616 non-null    object
#  33  Advancing_natual_environment                                    2320 non-null   object
#  34  Promoting_or_protecting_human_rights                            856 non-null    object
#  35  Purposes_beneficial_to_ther_general_public_and_other_analogous  7242 non-null   object
#  36  Promoting_reconciliation__mutual_respect_and_tolerance          1517 non-null   object
#  37  Advancing_Religion                                              17669 non-null  object
#  38  Advancing_social_or_public_welfare                              13249 non-null  object
#  39  Advancing_security_or_safety_of_Australia_or_Australian_public  1103 non-null   object
#  40  Aboriginal_or_TSI                                               14077 non-null  object
#  41  Adults                                                          24947 non-null  object
#  42  Aged_Persons                                                    22586 non-null  object
#  43  Children                                                        22878 non-null  object
#  44  Communities_Overseas                                            4945 non-null   object
#  45  Early_Childhood                                                 15685 non-null  object
#  46  Ethnic_Groups                                                   15040 non-null  object
#  47  Families                                                        24071 non-null  object
#  48  Females                                                         19794 non-null  object
#  49  Financially_Disadvantaged                                       16528 non-null  object
#  50  LGBTIQA+                                                        2773 non-null   object
#  51  General_Community_in_Australia                                  23493 non-null  object
#  52  Males                                                           18662 non-null  object
#  53  Migrants_Refugees_or_Asylum_Seekers                             3920 non-null   object
#  54  Other_Beneficiaries                                             3114 non-null   object
#  55  Other_Charities                                                 7114 non-null   object
#  56  People_at_risk_of_homelessness                                  10015 non-null  object
#  57  People_with_Chronic_Illness                                     8487 non-null   object
#  58  People_with_Disabilities                                        13950 non-null  object
#  59  Pre_Post_Release_Offenders                                      3799 non-null   object
#  60  Rural_Regional_Remote_Communities                               15338 non-null  object
#  61  Unemployed_Person                                               9726 non-null   object
#  62  Veterans_or_their_families                                      5868 non-null   object
#  63  Victims_of_crime                                                5554 non-null   object
#  64  Victims_of_Disasters                                            5062 non-null   object
#  65  Youth                                                           25566 non-null  object
#  66  animals                                                         2350 non-null   object
#  67  environment                                                     3120 non-null   object
#  68  other_gender_identities                                         542 non-null    object
# dtypes: float64(1), int64(1), object(67)
# memory usage: 32.8+ MB

# %%
# of the features
# the most of relevance are 
# Postcode - "local"
# Charity_Website - "details"
# and features from column index 28 on - "causes"
data.columns
# Out:
# Index(['ABN', 'Charity_Legal_Name', 'Other_Organisation_Names', 'Address_Type',
#        'Address_Line_1', 'Address_Line_2', 'Address_Line_3', 'Town_City',
#        'State', 'Postcode', 'Country', 'Charity_Website', 'Registration_Date',
#        'Date_Organisation_Established', 'Charity_Size',
#        'Number_of_Responsible_Persons', 'Financial_Year_End',
#        'Operates_in_ACT', 'Operates_in_NSW', 'Operates_in_NT',
#        'Operates_in_QLD', 'Operates_in_SA', 'Operates_in_TAS',
#        'Operates_in_VIC', 'Operates_in_WA', 'Operating_Countries', 'PBI',
#        'HPC', 'Preventing_or_relieving_suffering_of_animals',
#        'Advancing_Culture', 'Advancing_Education', 'Advancing_Health',
#        'Promote_or_oppose_a_change_to_law__government_poll_or_prac',
#        'Advancing_natual_environment', 'Promoting_or_protecting_human_rights',
#        'Purposes_beneficial_to_ther_general_public_and_other_analogous',
#        'Promoting_reconciliation__mutual_respect_and_tolerance',
#        'Advancing_Religion', 'Advancing_social_or_public_welfare',
#        'Advancing_security_or_safety_of_Australia_or_Australian_public',
#        'Aboriginal_or_TSI', 'Adults', 'Aged_Persons', 'Children',
#        'Communities_Overseas', 'Early_Childhood', 'Ethnic_Groups', 'Families',
#        'Females', 'Financially_Disadvantaged', 'LGBTIQA+',
#        'General_Community_in_Australia', 'Males',
#        'Migrants_Refugees_or_Asylum_Seekers', 'Other_Beneficiaries',
#        'Other_Charities', 'People_at_risk_of_homelessness',
#        'People_with_Chronic_Illness', 'People_with_Disabilities',
#        'Pre_Post_Release_Offenders', 'Rural_Regional_Remote_Communities',
#        'Unemployed_Person', 'Veterans_or_their_families', 'Victims_of_crime',
#        'Victims_of_Disasters', 'Youth', 'animals', 'environment',
#        'other_gender_identities'],
#       dtype='object')

# %% [markdown]
# It's worth highlighting that this file is missing information relative to previous years.
#
# Outstanding work is to hunt down descriptions provided by the charity, and potentially use an older file with more information (e.g. financials)
